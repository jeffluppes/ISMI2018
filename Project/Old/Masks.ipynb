# %% [markdown]
# # Creating circle masks

# %%
from matplotlib import pyplot as plt 
from keras import backend as K
from scipy.ndimage import imread  
from os.path import join
from PIL import Image

import os
import csv
import numpy as np

train_dir = '/projects/0/ismi2018/FINALPROJECTS/LYMPHOCYTE_DETECTION/train_images'
validation_dir = '/projects/0/ismi2018/FINALPROJECTS/LYMPHOCYTE_DETECTION/validation_images'
test_dir = '/projects/0/ismi2018/FINALPROJECTS/LYMPHOCYTE_DETECTION/test_images'
train_points ='/projects/0/ismi2018/FINALPROJECTS/LYMPHOCYTE_DETECTION/training_annotations.csv'
train_masks_dir = '/home/ruc0047/LYMPHOCYTE_DETECTION/train_masks'
# Out:
# /home/ruc0047/.local/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def split(x):
    return x.split(', ')

def createCircularMask(h, w, center, radius):
    Y, X = np.ogrid[:h, :w]
    dist_from_center = np.sqrt((X - center[0])**2 + (Y-center[1])**2)

    mask = dist_from_center <= radius
    return mask
    

def createMaskForImage(img_dir, image_path, center_csv, mask_dir, radius=6):
    image_name = image_path.split('.png')[0]
    image_id, roi = image_name.split('_ROI_')
    print('Processing {}'.format(image_name))
    
    image = plt.imread(join(img_dir, image_path))
    mask = np.zeros((image.shape[0], image.shape[1]))
    
    pois = []
    with open(center_csv) as file:
        pois = list(map(split, file.readlines()[1:]))
    
    pois = [poi for poi in pois if (poi[0] == image_id and poi[1] == roi)]

    for poi in pois:
        x = int(float(poi[3]))
        y = int(float(poi[4]))
        shape_mask = createCircularMask(image.shape[0], image.shape[1], [x, y], radius)
        mask[shape_mask] = 1
        
    mask_image = Image.fromarray(np.uint8(mask*255), 'L')
    mask_image.save(join(mask_dir, image_name + '_mask.png'))
    print('Created a mask for: {}'.format(image_name))

# %%
training_paths = os.listdir(train_dir)
mask_paths = os.listdir(train_masks_dir)
for path in training_paths:
    mask_name = path.split('.png')[0] + '_mask.png'
    if mask_name not in mask_paths:
        createMaskForImage(train_dir, path, train_points, train_masks_dir)
# Out:
# Processing T3C03L1A2B1S11R01_ROI_2
# Created a mask for: T3C03L1A2B1S11R01_ROI_2
# Processing 1080_CD3_ROI_3
# Created a mask for: 1080_CD3_ROI_3
# Processing 31_CD3_ROI_1
# Created a mask for: 31_CD3_ROI_1
# Processing 31_CD3_ROI_8
# Created a mask for: 31_CD3_ROI_8
# Processing T10-4360_I_AG_CD3_ROI_3
# Created a mask for: T10-4360_I_AG_CD3_ROI_3
# Processing T17-071825_III4_CD3_ROI_9
# Created a mask for: T17-071825_III4_CD3_ROI_9
# Processing T17-071841_III6_CD8_ROI_10
# Created a mask for: T17-071841_III6_CD8_ROI_10
# Processing T10-4360_I_AG_CD3_ROI_6
# Created a mask for: T10-4360_I_AG_CD3_ROI_6
# Processing 95-22625-I-4_CD8_ROI_5
# Created a mask for: 95-22625-I-4_CD8_ROI_5
# Processing T17-071823_III3_CD8_ROI_3
# Created a mask for: T17-071823_III3_CD8_ROI_3
# Processing T17-071549_III3_CD3_ROI_3
# Created a mask for: T17-071549_III3_CD3_ROI_3
# Processing T17-071823_III3_CD8_ROI_2
# Created a mask for: T17-071823_III3_CD8_ROI_2
# Processing 13_CD8_ROI_12
# Created a mask for: 13_CD8_ROI_12
# Processing 95-00909-II-L1_CD8_ROI_18
# Created a mask for: 95-00909-II-L1_CD8_ROI_18
# Processing 95-00149-G2_CD3_ROI_9
# Created a mask for: 95-00149-G2_CD3_ROI_9
# Processing 19-CD3_ROI_19
# Created a mask for: 19-CD3_ROI_19
# Processing 12-CD3_27.11.2014_17.27.31_ROI_4
# Created a mask for: 12-CD3_27.11.2014_17.27.31_ROI_4
# Processing 10_CD8_ROI_10
# Created a mask for: 10_CD8_ROI_10
# Processing 2-CD3_ROI_10
# Created a mask for: 2-CD3_ROI_10
# Processing T17-071841_III6_CD8_ROI_1
# Created a mask for: T17-071841_III6_CD8_ROI_1
# Processing T1C03L1A2B1S11R01_ROI_5
# Created a mask for: T1C03L1A2B1S11R01_ROI_5
# Processing T1C03L1A2B1S11R01_ROI_8
# Created a mask for: T1C03L1A2B1S11R01_ROI_8
# Processing T2C03L1A2B1S11R01_ROI_14
# Created a mask for: T2C03L1A2B1S11R01_ROI_14
# Processing T3C02L1A1B1S11R01_ROI_4
# Created a mask for: T3C02L1A1B1S11R01_ROI_4
# Processing 19-CD3_ROI_6
# Created a mask for: 19-CD3_ROI_6
# Processing 95-06642-F1_CD3_ROI_11
# Created a mask for: 95-06642-F1_CD3_ROI_11
# Processing T3C03L1A2B1S11R01_ROI_3
# Created a mask for: T3C03L1A2B1S11R01_ROI_3
# Processing 95-30827-5_CD3_ROI_1
# Created a mask for: 95-30827-5_CD3_ROI_1
# Processing 2-CD3_ROI_6
# Created a mask for: 2-CD3_ROI_6
# Processing 13_CD8_ROI_4
# Created a mask for: 13_CD8_ROI_4
# Processing T2C03L1A2B1S11R01_ROI_13
# Created a mask for: T2C03L1A2B1S11R01_ROI_13
# Processing 3_CD8_ROI_11
# Created a mask for: 3_CD8_ROI_11
# Processing 95-00149-G2_CD3_ROI_2
# Created a mask for: 95-00149-G2_CD3_ROI_2
# Processing T17-071549_III3_CD3_ROI_11
# Created a mask for: T17-071549_III3_CD3_ROI_11
# Processing T2C03L1A2B1S11R01_ROI_8
# Created a mask for: T2C03L1A2B1S11R01_ROI_8
# Processing 4_CD3_ROI_16
# Created a mask for: 4_CD3_ROI_16
# Processing 95-00149-G2_CD3_ROI_6
# Created a mask for: 95-00149-G2_CD3_ROI_6
# Processing T17-071841_III6_CD8_ROI_6
# Created a mask for: T17-071841_III6_CD8_ROI_6
# Processing T17-071549_III5_CD3_ROI_7
# Created a mask for: T17-071549_III5_CD3_ROI_7
# Processing T2C02L1A1B1S11R01_ROI_2
# Created a mask for: T2C02L1A1B1S11R01_ROI_2
# Processing 96-15186-C_CD3_ROI_14
# Created a mask for: 96-15186-C_CD3_ROI_14
# Processing 31_CD3_ROI_15
# Created a mask for: 31_CD3_ROI_15
# Processing T2C02L1A1B1S11R01_ROI_7
# Created a mask for: T2C02L1A1B1S11R01_ROI_7
# Processing 95-30827-5_CD3_ROI_6
# Created a mask for: 95-30827-5_CD3_ROI_6
# Processing 95-00149-G2_CD3_ROI_4
# Created a mask for: 95-00149-G2_CD3_ROI_4
# Processing T17-071823_III1_CD8_ROI_9
# Created a mask for: T17-071823_III1_CD8_ROI_9
# Processing T2C03L1A2B1S11R01_ROI_2
# Created a mask for: T2C03L1A2B1S11R01_ROI_2
# Processing T17-071841_III6_CD8_ROI_2
# Created a mask for: T17-071841_III6_CD8_ROI_2
# Processing 1002_CD3_ROI_3
# Created a mask for: 1002_CD3_ROI_3
# Processing 1080_CD3_ROI_7
# Created a mask for: 1080_CD3_ROI_7
# Processing 95-00909-II-L1_CD8_ROI_8
# Created a mask for: 95-00909-II-L1_CD8_ROI_8
# Processing 19-CD3_ROI_18
# Created a mask for: 19-CD3_ROI_18
# Processing T17-071549_III5_CD3_ROI_5
# Created a mask for: T17-071549_III5_CD3_ROI_5
# Processing T10-4360_I_Y_CD8_ROI_8
# Created a mask for: T10-4360_I_Y_CD8_ROI_8
# Processing 96-15186-C_CD3_ROI_3
# Created a mask for: 96-15186-C_CD3_ROI_3
# Processing 28_CD8_ROI_2
# Created a mask for: 28_CD8_ROI_2
# Processing 95-22625-I-4_CD8_ROI_2
# Created a mask for: 95-22625-I-4_CD8_ROI_2
# Processing 95-06642-F1_CD3_ROI_6
# Created a mask for: 95-06642-F1_CD3_ROI_6
# Processing 19-CD3_ROI_22
# Created a mask for: 19-CD3_ROI_22
# Processing 95-22625-I-4_CD8_ROI_1
# Created a mask for: 95-22625-I-4_CD8_ROI_1
# Processing T2C03L1A2B1S11R01_ROI_9
# Created a mask for: T2C03L1A2B1S11R01_ROI_9
# Processing 95-00909-II-L1_CD8_ROI_15
# Created a mask for: 95-00909-II-L1_CD8_ROI_15
# Processing 96-15186-C_CD3_ROI_6
# Created a mask for: 96-15186-C_CD3_ROI_6
# Processing 3_CD8_ROI_14
# Created a mask for: 3_CD8_ROI_14
# Processing 4_CD3_ROI_2
# Created a mask for: 4_CD3_ROI_2
# Processing 12-CD3_27.11.2014_17.27.31_ROI_13
# Created a mask for: 12-CD3_27.11.2014_17.27.31_ROI_13
# Processing T2C03L1A2B1S11R01_ROI_6
# Created a mask for: T2C03L1A2B1S11R01_ROI_6
# Processing 95-00909-II-L1_CD8_ROI_2
# Created a mask for: 95-00909-II-L1_CD8_ROI_2
# Processing T3C03L1A2B1S11R01_ROI_5
# Created a mask for: T3C03L1A2B1S11R01_ROI_5
# Processing 28_CD8_ROI_16
# Created a mask for: 28_CD8_ROI_16
# Processing 2-CD3_ROI_12
# Created a mask for: 2-CD3_ROI_12
# Processing 28_CD8_ROI_5
# Created a mask for: 28_CD8_ROI_5
# Processing T17-071825_III4_CD3_ROI_6
# Created a mask for: T17-071825_III4_CD3_ROI_6
# Processing T17-071827_III2_CD-3_ROI_5
# Created a mask for: T17-071827_III2_CD-3_ROI_5
# Processing T17-071549_III5_CD3_ROI_8
# Created a mask for: T17-071549_III5_CD3_ROI_8
# Processing 10_CD8_ROI_7
# Created a mask for: 10_CD8_ROI_7
# Processing T17-071825_III7_CD8_ROI_5
# Created a mask for: T17-071825_III7_CD8_ROI_5
# Processing 4_CD3_ROI_15
# Created a mask for: 4_CD3_ROI_15
# Processing T2C02L1A1B1S11R01_ROI_1
# Created a mask for: T2C02L1A1B1S11R01_ROI_1
# Processing 19-CD3_ROI_20
# Created a mask for: 19-CD3_ROI_20
# Processing 31_CD3_ROI_14
# Created a mask for: 31_CD3_ROI_14
# Processing 3_CD8_ROI_13
# Created a mask for: 3_CD8_ROI_13
# Processing 95-30827-5_CD3_ROI_9
# Created a mask for: 95-30827-5_CD3_ROI_9
# Processing 4_CD3_ROI_9
# Created a mask for: 4_CD3_ROI_9
# Processing T17-071825_III4_CD3_ROI_10
# Created a mask for: T17-071825_III4_CD3_ROI_10
# Processing 31_CD3_ROI_5
# Created a mask for: 31_CD3_ROI_5
# Processing 96-10846-G_CD3_ROI_3
# Created a mask for: 96-10846-G_CD3_ROI_3
# Processing T17-071825_III7_CD8_ROI_2
# Created a mask for: T17-071825_III7_CD8_ROI_2
# Processing T10-4360_I_AG_CD3_ROI_1
# Created a mask for: T10-4360_I_AG_CD3_ROI_1
# Processing T2C03L1A2B1S11R01_ROI_16
# Created a mask for: T2C03L1A2B1S11R01_ROI_16
# Processing 95-00149-G2_CD3_ROI_1
# Created a mask for: 95-00149-G2_CD3_ROI_1
# Processing T17-071823_III1_CD8_ROI_7
# Created a mask for: T17-071823_III1_CD8_ROI_7
# Processing 95-22625-I-4_CD8_ROI_6
# Created a mask for: 95-22625-I-4_CD8_ROI_6
# Processing 95-30827-5_CD3_ROI_12
# Created a mask for: 95-30827-5_CD3_ROI_12
# Processing 95-00909-II-L1_CD8_ROI_1
# Created a mask for: 95-00909-II-L1_CD8_ROI_1
# Processing 28_CD8_ROI_15
# Created a mask for: 28_CD8_ROI_15
# Processing 96-15186-C_CD3_ROI_8
# Created a mask for: 96-15186-C_CD3_ROI_8
# Processing 12-CD3_27.11.2014_17.27.31_ROI_9
# Created a mask for: 12-CD3_27.11.2014_17.27.31_ROI_9
# Processing T17-071823_III3_CD8_ROI_6
# Created a mask for: T17-071823_III3_CD8_ROI_6
# Processing 95-00909-II-L1_CD8_ROI_13
# Created a mask for: 95-00909-II-L1_CD8_ROI_13
# Processing 95-30827-5_CD3_ROI_2
# Created a mask for: 95-30827-5_CD3_ROI_2
# Processing 96-15186-C_CD3_ROI_10
# Created a mask for: 96-15186-C_CD3_ROI_10
# Processing T17-071549_III3_CD3_ROI_7
# Created a mask for: T17-071549_III3_CD3_ROI_7
# Processing 95-00909-II-L1_CD8_ROI_12
# Created a mask for: 95-00909-II-L1_CD8_ROI_12
# Processing T3C02L1A1B1S11R01_ROI_1
# Created a mask for: T3C02L1A1B1S11R01_ROI_1
# Processing T10-4360_I_Y_CD8_ROI_3
# Created a mask for: T10-4360_I_Y_CD8_ROI_3
# Processing T10-4360_I_Y_CD8_ROI_2
# Created a mask for: T10-4360_I_Y_CD8_ROI_2
# Processing 2-CD3_ROI_4
# Created a mask for: 2-CD3_ROI_4
# Processing 96-10846-G_CD3_ROI_1
# Created a mask for: 96-10846-G_CD3_ROI_1
# Processing 4_CD3_ROI_18
# Created a mask for: 4_CD3_ROI_18
# Processing T10-4360_I_AG_CD3_ROI_2
# Created a mask for: T10-4360_I_AG_CD3_ROI_2
# Processing 2-CD3_ROI_7
# Created a mask for: 2-CD3_ROI_7
# Processing 96-10846-G_CD3_ROI_4
# Created a mask for: 96-10846-G_CD3_ROI_4
# Processing T17-071841_III6_CD8_ROI_3
# Created a mask for: T17-071841_III6_CD8_ROI_3
# Processing 28_CD8_ROI_12
# Created a mask for: 28_CD8_ROI_12
# Processing 2-CD3_ROI_5
# Created a mask for: 2-CD3_ROI_5
# Processing 28_CD8_ROI_1
# Created a mask for: 28_CD8_ROI_1
# Processing 96-15186-C_CD3_ROI_5
# Created a mask for: 96-15186-C_CD3_ROI_5
# Processing 2-CD3_ROI_9
# Created a mask for: 2-CD3_ROI_9
# Processing 3_CD8_ROI_5
# Created a mask for: 3_CD8_ROI_5
# Processing 12-CD3_27.11.2014_17.27.31_ROI_8
# Created a mask for: 12-CD3_27.11.2014_17.27.31_ROI_8
# Processing 12-CD3_27.11.2014_17.27.31_ROI_14
# Created a mask for: 12-CD3_27.11.2014_17.27.31_ROI_14
# Processing T17-071825_III4_CD3_ROI_8
# Created a mask for: T17-071825_III4_CD3_ROI_8
# Processing 13_CD8_ROI_6
# Created a mask for: 13_CD8_ROI_6
# Processing 95-00909-II-L1_CD8_ROI_4
# Created a mask for: 95-00909-II-L1_CD8_ROI_4
# Processing 13_CD8_ROI_3
# Created a mask for: 13_CD8_ROI_3
# Processing T17-071549_III3_CD3_ROI_8
# Created a mask for: T17-071549_III3_CD3_ROI_8
# Processing T1C03L1A2B1S11R01_ROI_7
# Created a mask for: T1C03L1A2B1S11R01_ROI_7
# Processing T3C03L1A2B1S11R01_ROI_6
# Created a mask for: T3C03L1A2B1S11R01_ROI_6
# Processing 96-15186-C_CD3_ROI_1
# Created a mask for: 96-15186-C_CD3_ROI_1
# Processing T17-071549_III5_CD3_ROI_3
# Created a mask for: T17-071549_III5_CD3_ROI_3
# Processing 4_CD3_ROI_4
# Created a mask for: 4_CD3_ROI_4
# Processing 3_CD8_ROI_2
# Created a mask for: 3_CD8_ROI_2
# Processing 13_CD8_ROI_5
# Created a mask for: 13_CD8_ROI_5
# Processing 35_CD8_ROI_9
# Created a mask for: 35_CD8_ROI_9
# Processing 19-CD3_ROI_15
# Created a mask for: 19-CD3_ROI_15
# Processing T17-071825_III7_CD8_ROI_1
# Created a mask for: T17-071825_III7_CD8_ROI_1
# Processing 19-CD3_ROI_8
# Created a mask for: 19-CD3_ROI_8
# Processing 31_CD3_ROI_13
# Created a mask for: 31_CD3_ROI_13
# Processing T17-071841_III6_CD8_ROI_7
# Created a mask for: T17-071841_III6_CD8_ROI_7
# Processing 95-30827-5_CD3_ROI_7
# Created a mask for: 95-30827-5_CD3_ROI_7
# Processing 19-CD3_ROI_21
# Created a mask for: 19-CD3_ROI_21
# Processing 35_CD8_ROI_1
# Created a mask for: 35_CD8_ROI_1
# Processing 10_CD8_ROI_4
# Created a mask for: 10_CD8_ROI_4
# Processing 3_CD8_ROI_12
# Created a mask for: 3_CD8_ROI_12
# Processing 1080_CD3_ROI_4
# Created a mask for: 1080_CD3_ROI_4
# Processing 95-06642-F1_CD3_ROI_5
# Created a mask for: 95-06642-F1_CD3_ROI_5
# Processing T17-071823_III3_CD8_ROI_4
# Created a mask for: T17-071823_III3_CD8_ROI_4
# Processing 10_CD8_ROI_8
# Created a mask for: 10_CD8_ROI_8
# Processing 4_CD3_ROI_5
# Created a mask for: 4_CD3_ROI_5
# Processing T17-071823_III1_CD8_ROI_5
# Created a mask for: T17-071823_III1_CD8_ROI_5
# Processing T2C03L1A2B1S11R01_ROI_1
# Created a mask for: T2C03L1A2B1S11R01_ROI_1
# Processing 4_CD3_ROI_17
# Created a mask for: 4_CD3_ROI_17
# Processing T3C02L1A1B1S11R01_ROI_8
# Created a mask for: T3C02L1A1B1S11R01_ROI_8
# Processing 19-CD3_ROI_2
# Created a mask for: 19-CD3_ROI_2
# Processing 35_CD8_ROI_7
# Created a mask for: 35_CD8_ROI_7
# Processing 95-00909-II-L1_CD8_ROI_11
# Created a mask for: 95-00909-II-L1_CD8_ROI_11
# Processing T17-071549_III5_CD3_ROI_2
# Created a mask for: T17-071549_III5_CD3_ROI_2
# Processing 19-CD3_ROI_11
# Created a mask for: 19-CD3_ROI_11
# Processing T1C02L1A1B1S11R01_ROI_6
# Created a mask for: T1C02L1A1B1S11R01_ROI_6
# Processing 13_CD8_ROI_7
# Created a mask for: 13_CD8_ROI_7
# Processing T10-4360_I_AG_CD3_ROI_7
# Created a mask for: T10-4360_I_AG_CD3_ROI_7
# Processing T17-071549_III5_CD3_ROI_4
# Created a mask for: T17-071549_III5_CD3_ROI_4
# Processing 96-08919-4_CD8_ROI_3
# Created a mask for: 96-08919-4_CD8_ROI_3
# Processing T2C03L1A2B1S11R01_ROI_15
# Created a mask for: T2C03L1A2B1S11R01_ROI_15
# Processing T17-071827_III2_CD-3_ROI_10
# Created a mask for: T17-071827_III2_CD-3_ROI_10
# Processing T2C03L1A2B1S11R01_ROI_12
# Created a mask for: T2C03L1A2B1S11R01_ROI_12
# Processing 96-15186-C_CD3_ROI_9
# Created a mask for: 96-15186-C_CD3_ROI_9
# Processing 2-CD3_ROI_11
# Created a mask for: 2-CD3_ROI_11
# Processing T17-071841_III6_CD8_ROI_4
# Created a mask for: T17-071841_III6_CD8_ROI_4
# Processing 13_CD8_ROI_10
# Created a mask for: 13_CD8_ROI_10
# Processing 95-00909-II-L1_CD8_ROI_7
# Created a mask for: 95-00909-II-L1_CD8_ROI_7
# Processing T17-071825_III7_CD8_ROI_3
# Created a mask for: T17-071825_III7_CD8_ROI_3
# Processing T17-071823_III3_CD8_ROI_8
# Created a mask for: T17-071823_III3_CD8_ROI_8
# Processing 19-CD3_ROI_14
# Created a mask for: 19-CD3_ROI_14
# Processing T17-071549_III5_CD3_ROI_11
# Created a mask for: T17-071549_III5_CD3_ROI_11
# Processing 13_CD8_ROI_15
# Created a mask for: 13_CD8_ROI_15
# Processing 19-CD3_ROI_5
# Created a mask for: 19-CD3_ROI_5
# Processing 35_CD8_ROI_6
# Created a mask for: 35_CD8_ROI_6
# Processing 28_CD8_ROI_10
# Created a mask for: 28_CD8_ROI_10
# Processing 96-08919-4_CD8_ROI_5
# Created a mask for: 96-08919-4_CD8_ROI_5
# Processing T17-071823_III1_CD8_ROI_3
# Created a mask for: T17-071823_III1_CD8_ROI_3
# Processing 2-CD3_ROI_2
# Created a mask for: 2-CD3_ROI_2
# Processing T2C03L1A2B1S11R01_ROI_17
# Created a mask for: T2C03L1A2B1S11R01_ROI_17
# Processing 95-06642-F1_CD3_ROI_9
# Created a mask for: 95-06642-F1_CD3_ROI_9
# Processing 19-CD3_ROI_4
# Created a mask for: 19-CD3_ROI_4
# Processing 31_CD3_ROI_4
# Created a mask for: 31_CD3_ROI_4
# Processing 19-CD3_ROI_9
# Created a mask for: 19-CD3_ROI_9
# Processing 4_CD3_ROI_7
# Created a mask for: 4_CD3_ROI_7
# Processing T17-071549_III5_CD3_ROI_9
# Created a mask for: T17-071549_III5_CD3_ROI_9
# Processing 95-00909-II-L1_CD8_ROI_5
# Created a mask for: 95-00909-II-L1_CD8_ROI_5
# Processing 37_CD3_ROI_5
# Created a mask for: 37_CD3_ROI_5
# Processing T2C03L1A2B1S11R01_ROI_11
# Created a mask for: T2C03L1A2B1S11R01_ROI_11
# Processing 1080_CD3_ROI_2
# Created a mask for: 1080_CD3_ROI_2
# Processing 31_CD3_ROI_12
# Created a mask for: 31_CD3_ROI_12
# Processing T3C02L1A1B1S11R01_ROI_7
# Created a mask for: T3C02L1A1B1S11R01_ROI_7
# Processing T17-071827_III2_CD-3_ROI_8
# Created a mask for: T17-071827_III2_CD-3_ROI_8
# Processing T17-071823_III1_CD8_ROI_4
# Created a mask for: T17-071823_III1_CD8_ROI_4
# Processing 95-06642-F1_CD3_ROI_8
# Created a mask for: 95-06642-F1_CD3_ROI_8
# Processing 28_CD8_ROI_11
# Created a mask for: 28_CD8_ROI_11
# Processing T1C02L1A1B1S11R01_ROI_8
# Created a mask for: T1C02L1A1B1S11R01_ROI_8
# Processing 3_CD8_ROI_3
# Created a mask for: 3_CD8_ROI_3
# Processing 19-CD3_ROI_23
# Created a mask for: 19-CD3_ROI_23
# Processing 95-06642-F1_CD3_ROI_3
# Created a mask for: 95-06642-F1_CD3_ROI_3
# Processing 28_CD8_ROI_6
# Created a mask for: 28_CD8_ROI_6
# Processing T2C03L1A2B1S11R01_ROI_3
# Created a mask for: T2C03L1A2B1S11R01_ROI_3
# Processing T17-071823_III1_CD8_ROI_8
# Created a mask for: T17-071823_III1_CD8_ROI_8
# Processing 35_CD8_ROI_4
# Created a mask for: 35_CD8_ROI_4
# Processing 10_CD8_ROI_3
# Created a mask for: 10_CD8_ROI_3
# Processing 4_CD3_ROI_8
# Created a mask for: 4_CD3_ROI_8
# Processing 10_CD8_ROI_2
# Created a mask for: 10_CD8_ROI_2
# Processing T17-071827_III2_CD-3_ROI_6
# Created a mask for: T17-071827_III2_CD-3_ROI_6
# Processing T17-071825_III7_CD8_ROI_6
# Created a mask for: T17-071825_III7_CD8_ROI_6
# Processing T10-4360_I_Y_CD8_ROI_7
# Created a mask for: T10-4360_I_Y_CD8_ROI_7
# Processing 3_CD8_ROI_15
# Created a mask for: 3_CD8_ROI_15
# Processing T10-4360_I_Y_CD8_ROI_9
# Created a mask for: T10-4360_I_Y_CD8_ROI_9
# Processing 4_CD3_ROI_1
# Created a mask for: 4_CD3_ROI_1
# Processing 95-06642-F1_CD3_ROI_7
# Created a mask for: 95-06642-F1_CD3_ROI_7
# Processing 37_CD3_ROI_3
# Created a mask for: 37_CD3_ROI_3
# Processing 19-CD3_ROI_12
# Created a mask for: 19-CD3_ROI_12
# Processing 96-15186-C_CD3_ROI_2
# Created a mask for: 96-15186-C_CD3_ROI_2
# Processing 96-08919-4_CD8_ROI_2
# Created a mask for: 96-08919-4_CD8_ROI_2
# Processing 28_CD8_ROI_8
# Created a mask for: 28_CD8_ROI_8

# %%
2-CD3_ROI_8
